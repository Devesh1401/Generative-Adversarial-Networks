# %%
import tensorflow as tf 
print(tf.__version__)
# Out:
# 2.5.0

# %%
from tensorflow.keras.layers import Input,Dense,LeakyReLU,Dropout,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD,Adam
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys,os

# %%
from keras.datasets import fashion_mnist
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
x_train,x_test = x_train/255.0*2-1 , x_test/255.0*2-1
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
# Flattening data
N,H,W = x_train.shape
D = H*W
x_train = x_train.reshape(-1,D)
x_test  =  x_test.reshape(-1,D)
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
latent_dim = 100

# %%
# creating generator network
def build_generator(latent_dim):
  i = Input(shape=(latent_dim,))
  x = Dense(256,activation=LeakyReLU(alpha=0.2))(i)
  x = BatchNormalization(momentum=0.7)(x)
  x = Dense(512,activation=LeakyReLU(alpha=0.2))(x)
  x = BatchNormalization(momentum=0.7)(x)
  x = Dense(1024,activation=LeakyReLU(alpha=0.2))(x)
  x = BatchNormalization(momentum=0.7)(x)
  x = Dense(D , activation='tanh')(x)
  model = Model(i,x)
  return model

# %%
# creating discriminator network
def build_discriminator(img_size):
  i = Input(shape=(img_size,))
  x = Dense(512,activation=LeakyReLU(alpha=0.2))(i)
  x = Dense(256,activation=LeakyReLU(alpha=0.2))(x)
  x = Dense(1,activation='sigmoid')(x)
  model = Model(i,x)
  return model

# %%
# Compiling Models 
discriminator = build_discriminator(D)
discriminator.compile(loss='binary_crossentropy',optimizer=Adam(0.0002,0.5),metrics=['accuracy'])
generator = build_generator(latent_dim)
z = Input(shape=(latent_dim,))
img = generator(z)
discriminator.trainable=False
fake_pred = discriminator(img)
combined_model = Model(z,fake_pred)
combined_model.compile(loss='binary_crossentropy',optimizer=Adam(0.0002,0.5))

# %%
# Train the GAN
batch_size = 32
epochs = 30000
sample_period = 200
ones = np.ones(batch_size)
zeros = np.zeros(batch_size)
d_losses = []
g_losses = []
if not os.path.exists('gan_images'):
  os.makedirs('gan_images')

# %%
def sample_images(epoch):
  rows,cols = 5,5
  noise = np.random.randn(rows*cols , latent_dim)
  imgs = generator.predict(noise)
  imgs = 0.5 * imgs + 0.5
  fig , axs = plt.subplots(rows,cols)
  idx = 0
  for i in range(rows):
    for j in range(cols):
      axs[i,j].imshow(imgs[idx].reshape(H,W),cmap='gray')
      axs[i,j].axis('off')
      idx+=1
  fig.savefig('gan_images/%d.png'%epoch)
  plt.close()

# %%
# Main Training Loop
for epoch in range(epochs):
  # select random batch of images
  idx = np.random.randint(0,x_train.shape[0],batch_size)
  real_imgs = x_train[idx]

  # Generate fake images
  noise = np.random.randn(batch_size,latent_dim)
  fake_imgs = generator.predict(noise)

  # train the discriminator 
  # both accuracy and loss are returned
  d_loss_real , d_acc_real = discriminator.train_on_batch(real_imgs,ones)
  d_loss_fake , d_acc_fake = discriminator.train_on_batch(fake_imgs,zeros)
  d_loss = 0.5*(d_loss_real+d_loss_fake)
  d_acc = 0.5*(d_acc_real+d_acc_fake)

  # train generative combined model
  noise = np.random.randn(batch_size,latent_dim)
  gloss = combined_model.train_on_batch(noise,ones)

  # do it again
  noise = np.random.randn(batch_size,latent_dim)
  g_loss = combined_model.train_on_batch(noise,ones)

  # save the losses
  d_losses.append(d_loss)
  g_losses.append(g_loss)

  if epoch % 100 == 0:
    print(f"epoch: {epoch+1}/{epoch}, d_loss:{d_loss:.2f}, d_acc:{d_acc:.2f}, g_loss:{g_loss:.2f}")

  if epoch % 200 == 0:
    sample_images(epoch)
# Out:
# epoch: 1/0, d_loss:0.44, d_acc:0.88, g_loss:0.87
# epoch: 101/100, d_loss:0.30, d_acc:0.88, g_loss:2.96
# epoch: 201/200, d_loss:0.94, d_acc:0.44, g_loss:1.18
# epoch: 301/300, d_loss:0.67, d_acc:0.59, g_loss:0.70
# epoch: 401/400, d_loss:0.72, d_acc:0.47, g_loss:0.72
# epoch: 501/500, d_loss:0.67, d_acc:0.53, g_loss:0.70
# epoch: 601/600, d_loss:0.70, d_acc:0.50, g_loss:0.82
# epoch: 701/700, d_loss:0.68, d_acc:0.50, g_loss:0.70
# epoch: 801/800, d_loss:0.69, d_acc:0.48, g_loss:0.71
# epoch: 901/900, d_loss:0.67, d_acc:0.47, g_loss:0.72
# epoch: 1001/1000, d_loss:0.65, d_acc:0.69, g_loss:0.71
# epoch: 1101/1100, d_loss:0.62, d_acc:0.70, g_loss:0.77
# epoch: 1201/1200, d_loss:0.65, d_acc:0.56, g_loss:0.75
# epoch: 1301/1300, d_loss:0.73, d_acc:0.52, g_loss:0.81
# epoch: 1401/1400, d_loss:0.66, d_acc:0.62, g_loss:0.73
# epoch: 1501/1500, d_loss:0.68, d_acc:0.52, g_loss:0.73
# epoch: 1601/1600, d_loss:0.70, d_acc:0.48, g_loss:0.75
# epoch: 1701/1700, d_loss:0.66, d_acc:0.64, g_loss:0.71
# epoch: 1801/1800, d_loss:0.70, d_acc:0.53, g_loss:0.71
# epoch: 1901/1900, d_loss:0.66, d_acc:0.58, g_loss:0.71
# epoch: 2001/2000, d_loss:0.66, d_acc:0.62, g_loss:0.75
# epoch: 2101/2100, d_loss:0.69, d_acc:0.64, g_loss:0.70
# epoch: 2201/2200, d_loss:0.66, d_acc:0.61, g_loss:0.72
# epoch: 2301/2300, d_loss:0.69, d_acc:0.56, g_loss:0.74
# epoch: 2401/2400, d_loss:0.66, d_acc:0.58, g_loss:0.76
# epoch: 2501/2500, d_loss:0.69, d_acc:0.55, g_loss:0.75
# epoch: 2601/2600, d_loss:0.71, d_acc:0.56, g_loss:0.72
# epoch: 2701/2700, d_loss:0.69, d_acc:0.55, g_loss:0.75
# epoch: 2801/2800, d_loss:0.67, d_acc:0.64, g_loss:0.76
# epoch: 2901/2900, d_loss:0.74, d_acc:0.41, g_loss:0.74
# epoch: 3001/3000, d_loss:0.67, d_acc:0.64, g_loss:0.84
# epoch: 3101/3100, d_loss:0.67, d_acc:0.64, g_loss:0.73
# epoch: 3201/3200, d_loss:0.69, d_acc:0.50, g_loss:0.77
# epoch: 3301/3300, d_loss:0.69, d_acc:0.64, g_loss:0.73
# epoch: 3401/3400, d_loss:0.68, d_acc:0.53, g_loss:0.75
# epoch: 3501/3500, d_loss:0.72, d_acc:0.41, g_loss:0.76
# epoch: 3601/3600, d_loss:0.71, d_acc:0.55, g_loss:0.81
# epoch: 3701/3700, d_loss:0.68, d_acc:0.45, g_loss:0.75
# epoch: 3801/3800, d_loss:0.71, d_acc:0.36, g_loss:0.79
# epoch: 3901/3900, d_loss:0.71, d_acc:0.55, g_loss:0.80
# epoch: 4001/4000, d_loss:0.70, d_acc:0.52, g_loss:0.73
# epoch: 4101/4100, d_loss:0.71, d_acc:0.44, g_loss:0.76
# epoch: 4201/4200, d_loss:0.73, d_acc:0.42, g_loss:0.74
# epoch: 4301/4300, d_loss:0.69, d_acc:0.42, g_loss:0.75
# epoch: 4401/4400, d_loss:0.72, d_acc:0.48, g_loss:0.73
# epoch: 4501/4500, d_loss:0.69, d_acc:0.45, g_loss:0.73
# epoch: 4601/4600, d_loss:0.73, d_acc:0.53, g_loss:0.77
# epoch: 4701/4700, d_loss:0.70, d_acc:0.50, g_loss:0.78
# epoch: 4801/4800, d_loss:0.69, d_acc:0.53, g_loss:0.72
# epoch: 4901/4900, d_loss:0.71, d_acc:0.52, g_loss:0.78
# epoch: 5001/5000, d_loss:0.65, d_acc:0.62, g_loss:0.80
# epoch: 5101/5100, d_loss:0.69, d_acc:0.58, g_loss:0.77
# epoch: 5201/5200, d_loss:0.70, d_acc:0.42, g_loss:0.76
# epoch: 5301/5300, d_loss:0.71, d_acc:0.44, g_loss:0.73
# epoch: 5401/5400, d_loss:0.68, d_acc:0.52, g_loss:0.76
# epoch: 5501/5500, d_loss:0.70, d_acc:0.47, g_loss:0.79
# epoch: 5601/5600, d_loss:0.72, d_acc:0.52, g_loss:0.73
# epoch: 5701/5700, d_loss:0.70, d_acc:0.53, g_loss:0.72
# epoch: 5801/5800, d_loss:0.69, d_acc:0.59, g_loss:0.77
# epoch: 5901/5900, d_loss:0.69, d_acc:0.55, g_loss:0.75
# epoch: 6001/6000, d_loss:0.66, d_acc:0.58, g_loss:0.75
# epoch: 6101/6100, d_loss:0.70, d_acc:0.45, g_loss:0.72
# epoch: 6201/6200, d_loss:0.71, d_acc:0.44, g_loss:0.73
# epoch: 6301/6300, d_loss:0.69, d_acc:0.48, g_loss:0.72
# epoch: 6401/6400, d_loss:0.69, d_acc:0.53, g_loss:0.74
# epoch: 6501/6500, d_loss:0.67, d_acc:0.58, g_loss:0.73
# epoch: 6601/6600, d_loss:0.68, d_acc:0.53, g_loss:0.75
# epoch: 6701/6700, d_loss:0.71, d_acc:0.52, g_loss:0.75
# epoch: 6801/6800, d_loss:0.70, d_acc:0.45, g_loss:0.71
# epoch: 6901/6900, d_loss:0.75, d_acc:0.41, g_loss:0.76
# epoch: 7001/7000, d_loss:0.69, d_acc:0.50, g_loss:0.76
# epoch: 7101/7100, d_loss:0.70, d_acc:0.52, g_loss:0.73
# epoch: 7201/7200, d_loss:0.68, d_acc:0.56, g_loss:0.78
# epoch: 7301/7300, d_loss:0.68, d_acc:0.52, g_loss:0.74
# epoch: 7401/7400, d_loss:0.71, d_acc:0.42, g_loss:0.72
# epoch: 7501/7500, d_loss:0.67, d_acc:0.58, g_loss:0.70
# epoch: 7601/7600, d_loss:0.72, d_acc:0.42, g_loss:0.68
# epoch: 7701/7700, d_loss:0.71, d_acc:0.47, g_loss:0.72
# epoch: 7801/7800, d_loss:0.70, d_acc:0.53, g_loss:0.71
# epoch: 7901/7900, d_loss:0.70, d_acc:0.45, g_loss:0.74
# epoch: 8001/8000, d_loss:0.75, d_acc:0.34, g_loss:0.73
# epoch: 8101/8100, d_loss:0.70, d_acc:0.44, g_loss:0.70
# epoch: 8201/8200, d_loss:0.71, d_acc:0.44, g_loss:0.72
# epoch: 8301/8300, d_loss:0.69, d_acc:0.53, g_loss:0.74
# epoch: 8401/8400, d_loss:0.69, d_acc:0.52, g_loss:0.77
# epoch: 8501/8500, d_loss:0.69, d_acc:0.53, g_loss:0.73
# epoch: 8601/8600, d_loss:0.70, d_acc:0.58, g_loss:0.73
# epoch: 8701/8700, d_loss:0.70, d_acc:0.48, g_loss:0.75
# epoch: 8801/8800, d_loss:0.69, d_acc:0.50, g_loss:0.78
# epoch: 8901/8900, d_loss:0.73, d_acc:0.38, g_loss:0.70
# epoch: 9001/9000, d_loss:0.68, d_acc:0.61, g_loss:0.73
# epoch: 9101/9100, d_loss:0.68, d_acc:0.55, g_loss:0.74
# epoch: 9201/9200, d_loss:0.71, d_acc:0.39, g_loss:0.75
# epoch: 9301/9300, d_loss:0.70, d_acc:0.56, g_loss:0.69
# epoch: 9401/9400, d_loss:0.72, d_acc:0.39, g_loss:0.78
# epoch: 9501/9500, d_loss:0.70, d_acc:0.44, g_loss:0.72
# epoch: 9601/9600, d_loss:0.68, d_acc:0.59, g_loss:0.73
# epoch: 9701/9700, d_loss:0.70, d_acc:0.52, g_loss:0.73
# epoch: 9801/9800, d_loss:0.70, d_acc:0.52, g_loss:0.72
# epoch: 9901/9900, d_loss:0.68, d_acc:0.56, g_loss:0.71
# epoch: 10001/10000, d_loss:0.72, d_acc:0.44, g_loss:0.75
# epoch: 10101/10100, d_loss:0.71, d_acc:0.55, g_loss:0.73
# epoch: 10201/10200, d_loss:0.67, d_acc:0.64, g_loss:0.73
# epoch: 10301/10300, d_loss:0.66, d_acc:0.58, g_loss:0.73
# epoch: 10401/10400, d_loss:0.69, d_acc:0.48, g_loss:0.73
# epoch: 10501/10500, d_loss:0.69, d_acc:0.56, g_loss:0.72
# epoch: 10601/10600, d_loss:0.69, d_acc:0.47, g_loss:0.76
# epoch: 10701/10700, d_loss:0.69, d_acc:0.55, g_loss:0.72
# epoch: 10801/10800, d_loss:0.69, d_acc:0.56, g_loss:0.71
# epoch: 10901/10900, d_loss:0.71, d_acc:0.55, g_loss:0.76
# epoch: 11001/11000, d_loss:0.71, d_acc:0.45, g_loss:0.73
# epoch: 11101/11100, d_loss:0.72, d_acc:0.44, g_loss:0.73
# epoch: 11201/11200, d_loss:0.69, d_acc:0.58, g_loss:0.74
# epoch: 11301/11300, d_loss:0.71, d_acc:0.50, g_loss:0.72
# epoch: 11401/11400, d_loss:0.71, d_acc:0.44, g_loss:0.72
# epoch: 11501/11500, d_loss:0.69, d_acc:0.53, g_loss:0.76
# epoch: 11601/11600, d_loss:0.69, d_acc:0.50, g_loss:0.76
# epoch: 11701/11700, d_loss:0.68, d_acc:0.59, g_loss:0.72
# epoch: 11801/11800, d_loss:0.69, d_acc:0.50, g_loss:0.73
# epoch: 11901/11900, d_loss:0.69, d_acc:0.47, g_loss:0.75
# epoch: 12001/12000, d_loss:0.69, d_acc:0.50, g_loss:0.72
# epoch: 12101/12100, d_loss:0.68, d_acc:0.55, g_loss:0.75
# epoch: 12201/12200, d_loss:0.68, d_acc:0.53, g_loss:0.76
# epoch: 12301/12300, d_loss:0.70, d_acc:0.47, g_loss:0.71
# epoch: 12401/12400, d_loss:0.67, d_acc:0.59, g_loss:0.71
# epoch: 12501/12500, d_loss:0.69, d_acc:0.53, g_loss:0.72
# epoch: 12601/12600, d_loss:0.73, d_acc:0.41, g_loss:0.72
# epoch: 12701/12700, d_loss:0.68, d_acc:0.59, g_loss:0.76
# epoch: 12801/12800, d_loss:0.71, d_acc:0.55, g_loss:0.71
# epoch: 12901/12900, d_loss:0.67, d_acc:0.52, g_loss:0.74
# epoch: 13001/13000, d_loss:0.68, d_acc:0.59, g_loss:0.71
# epoch: 13101/13100, d_loss:0.68, d_acc:0.56, g_loss:0.74
# epoch: 13201/13200, d_loss:0.71, d_acc:0.45, g_loss:0.75
# epoch: 13301/13300, d_loss:0.69, d_acc:0.48, g_loss:0.72
# epoch: 13401/13400, d_loss:0.70, d_acc:0.50, g_loss:0.70
# epoch: 13501/13500, d_loss:0.68, d_acc:0.53, g_loss:0.73
# epoch: 13601/13600, d_loss:0.68, d_acc:0.53, g_loss:0.72
# epoch: 13701/13700, d_loss:0.68, d_acc:0.64, g_loss:0.72
# epoch: 13801/13800, d_loss:0.69, d_acc:0.56, g_loss:0.74
# epoch: 13901/13900, d_loss:0.69, d_acc:0.50, g_loss:0.73
# epoch: 14001/14000, d_loss:0.69, d_acc:0.59, g_loss:0.73
# epoch: 14101/14100, d_loss:0.68, d_acc:0.55, g_loss:0.70
# epoch: 14201/14200, d_loss:0.68, d_acc:0.55, g_loss:0.75
# epoch: 14301/14300, d_loss:0.66, d_acc:0.66, g_loss:0.75
# epoch: 14401/14400, d_loss:0.71, d_acc:0.47, g_loss:0.74
# epoch: 14501/14500, d_loss:0.65, d_acc:0.70, g_loss:0.79
# epoch: 14601/14600, d_loss:0.65, d_acc:0.66, g_loss:0.72
# epoch: 14701/14700, d_loss:0.70, d_acc:0.42, g_loss:0.76
# epoch: 14801/14800, d_loss:0.68, d_acc:0.58, g_loss:0.73
# epoch: 14901/14900, d_loss:0.70, d_acc:0.44, g_loss:0.78
# epoch: 15001/15000, d_loss:0.69, d_acc:0.55, g_loss:0.71
# epoch: 15101/15100, d_loss:0.70, d_acc:0.44, g_loss:0.71
# epoch: 15201/15200, d_loss:0.73, d_acc:0.39, g_loss:0.74
# epoch: 15301/15300, d_loss:0.70, d_acc:0.50, g_loss:0.75
# epoch: 15401/15400, d_loss:0.70, d_acc:0.52, g_loss:0.73
# epoch: 15501/15500, d_loss:0.68, d_acc:0.56, g_loss:0.76
# epoch: 15601/15600, d_loss:0.69, d_acc:0.56, g_loss:0.70
# epoch: 15701/15700, d_loss:0.69, d_acc:0.50, g_loss:0.75
# epoch: 15801/15800, d_loss:0.71, d_acc:0.52, g_loss:0.73
# epoch: 15901/15900, d_loss:0.70, d_acc:0.55, g_loss:0.74
# epoch: 16001/16000, d_loss:0.68, d_acc:0.55, g_loss:0.72
# epoch: 16101/16100, d_loss:0.68, d_acc:0.55, g_loss:0.73
# epoch: 16201/16200, d_loss:0.69, d_acc:0.52, g_loss:0.73
# epoch: 16301/16300, d_loss:0.72, d_acc:0.45, g_loss:0.71
# epoch: 16401/16400, d_loss:0.68, d_acc:0.59, g_loss:0.71
# epoch: 16501/16500, d_loss:0.70, d_acc:0.59, g_loss:0.71
# epoch: 16601/16600, d_loss:0.67, d_acc:0.62, g_loss:0.74
# epoch: 16701/16700, d_loss:0.68, d_acc:0.53, g_loss:0.73
# epoch: 16801/16800, d_loss:0.70, d_acc:0.42, g_loss:0.71
# epoch: 16901/16900, d_loss:0.67, d_acc:0.48, g_loss:0.74
# epoch: 17001/17000, d_loss:0.67, d_acc:0.66, g_loss:0.75
# epoch: 17101/17100, d_loss:0.72, d_acc:0.42, g_loss:0.70
# epoch: 17201/17200, d_loss:0.70, d_acc:0.45, g_loss:0.73
# epoch: 17301/17300, d_loss:0.68, d_acc:0.56, g_loss:0.74
# epoch: 17401/17400, d_loss:0.71, d_acc:0.47, g_loss:0.72
# epoch: 17501/17500, d_loss:0.67, d_acc:0.58, g_loss:0.77
# epoch: 17601/17600, d_loss:0.68, d_acc:0.62, g_loss:0.76
# epoch: 17701/17700, d_loss:0.70, d_acc:0.45, g_loss:0.75
# epoch: 17801/17800, d_loss:0.73, d_acc:0.44, g_loss:0.74
# epoch: 17901/17900, d_loss:0.72, d_acc:0.52, g_loss:0.75
# epoch: 18001/18000, d_loss:0.69, d_acc:0.48, g_loss:0.74
# epoch: 18101/18100, d_loss:0.70, d_acc:0.48, g_loss:0.71
# epoch: 18201/18200, d_loss:0.69, d_acc:0.56, g_loss:0.74
# epoch: 18301/18300, d_loss:0.68, d_acc:0.56, g_loss:0.76
# epoch: 18401/18400, d_loss:0.72, d_acc:0.45, g_loss:0.71
# epoch: 18501/18500, d_loss:0.66, d_acc:0.64, g_loss:0.72
# epoch: 18601/18600, d_loss:0.70, d_acc:0.48, g_loss:0.72
# epoch: 18701/18700, d_loss:0.72, d_acc:0.36, g_loss:0.71
# epoch: 18801/18800, d_loss:0.74, d_acc:0.34, g_loss:0.74
# epoch: 18901/18900, d_loss:0.68, d_acc:0.56, g_loss:0.75
# epoch: 19001/19000, d_loss:0.70, d_acc:0.44, g_loss:0.73
# epoch: 19101/19100, d_loss:0.69, d_acc:0.44, g_loss:0.74
# epoch: 19201/19200, d_loss:0.69, d_acc:0.55, g_loss:0.72
# epoch: 19301/19300, d_loss:0.71, d_acc:0.52, g_loss:0.74
# epoch: 19401/19400, d_loss:0.69, d_acc:0.56, g_loss:0.75
# epoch: 19501/19500, d_loss:0.69, d_acc:0.55, g_loss:0.73
# epoch: 19601/19600, d_loss:0.69, d_acc:0.55, g_loss:0.74
# epoch: 19701/19700, d_loss:0.70, d_acc:0.53, g_loss:0.73
# epoch: 19801/19800, d_loss:0.70, d_acc:0.48, g_loss:0.74
# epoch: 19901/19900, d_loss:0.69, d_acc:0.55, g_loss:0.76
# epoch: 20001/20000, d_loss:0.69, d_acc:0.53, g_loss:0.74
# epoch: 20101/20100, d_loss:0.70, d_acc:0.50, g_loss:0.76
# epoch: 20201/20200, d_loss:0.67, d_acc:0.59, g_loss:0.72
# epoch: 20301/20300, d_loss:0.74, d_acc:0.36, g_loss:0.72
# epoch: 20401/20400, d_loss:0.69, d_acc:0.58, g_loss:0.74
# epoch: 20501/20500, d_loss:0.69, d_acc:0.55, g_loss:0.74
# epoch: 20601/20600, d_loss:0.68, d_acc:0.55, g_loss:0.75
# epoch: 20701/20700, d_loss:0.68, d_acc:0.61, g_loss:0.72
# epoch: 20801/20800, d_loss:0.67, d_acc:0.55, g_loss:0.71
# epoch: 20901/20900, d_loss:0.69, d_acc:0.52, g_loss:0.75
# epoch: 21001/21000, d_loss:0.70, d_acc:0.55, g_loss:0.75
# epoch: 21101/21100, d_loss:0.71, d_acc:0.47, g_loss:0.75
# epoch: 21201/21200, d_loss:0.65, d_acc:0.62, g_loss:0.70
# epoch: 21301/21300, d_loss:0.70, d_acc:0.48, g_loss:0.75
# epoch: 21401/21400, d_loss:0.70, d_acc:0.48, g_loss:0.73
# epoch: 21501/21500, d_loss:0.68, d_acc:0.59, g_loss:0.71
# epoch: 21601/21600, d_loss:0.72, d_acc:0.33, g_loss:0.74
# epoch: 21701/21700, d_loss:0.66, d_acc:0.58, g_loss:0.74
# epoch: 21801/21800, d_loss:0.67, d_acc:0.61, g_loss:0.76
# epoch: 21901/21900, d_loss:0.69, d_acc:0.58, g_loss:0.75
# epoch: 22001/22000, d_loss:0.68, d_acc:0.53, g_loss:0.73
# epoch: 22101/22100, d_loss:0.69, d_acc:0.53, g_loss:0.74
# epoch: 22201/22200, d_loss:0.69, d_acc:0.55, g_loss:0.73
# epoch: 22301/22300, d_loss:0.68, d_acc:0.62, g_loss:0.74
# epoch: 22401/22400, d_loss:0.73, d_acc:0.47, g_loss:0.73
# epoch: 22501/22500, d_loss:0.71, d_acc:0.42, g_loss:0.73
# epoch: 22601/22600, d_loss:0.72, d_acc:0.41, g_loss:0.72
# epoch: 22701/22700, d_loss:0.70, d_acc:0.52, g_loss:0.73
# epoch: 22801/22800, d_loss:0.68, d_acc:0.59, g_loss:0.79
# epoch: 22901/22900, d_loss:0.70, d_acc:0.55, g_loss:0.73
# epoch: 23001/23000, d_loss:0.68, d_acc:0.53, g_loss:0.74
# epoch: 23101/23100, d_loss:0.66, d_acc:0.62, g_loss:0.76
# epoch: 23201/23200, d_loss:0.69, d_acc:0.53, g_loss:0.73
# epoch: 23301/23300, d_loss:0.70, d_acc:0.52, g_loss:0.76
# epoch: 23401/23400, d_loss:0.72, d_acc:0.45, g_loss:0.72
# epoch: 23501/23500, d_loss:0.68, d_acc:0.56, g_loss:0.72
# epoch: 23601/23600, d_loss:0.70, d_acc:0.47, g_loss:0.75
# epoch: 23701/23700, d_loss:0.70, d_acc:0.44, g_loss:0.75
# epoch: 23801/23800, d_loss:0.68, d_acc:0.58, g_loss:0.74
# epoch: 23901/23900, d_loss:0.69, d_acc:0.64, g_loss:0.78
# epoch: 24001/24000, d_loss:0.72, d_acc:0.50, g_loss:0.76
# epoch: 24101/24100, d_loss:0.66, d_acc:0.59, g_loss:0.80
# epoch: 24201/24200, d_loss:0.69, d_acc:0.59, g_loss:0.78
# epoch: 24301/24300, d_loss:0.66, d_acc:0.64, g_loss:0.72
# epoch: 24401/24400, d_loss:0.66, d_acc:0.66, g_loss:0.71
# epoch: 24501/24500, d_loss:0.69, d_acc:0.50, g_loss:0.76
# epoch: 24601/24600, d_loss:0.71, d_acc:0.52, g_loss:0.73
# epoch: 24701/24700, d_loss:0.68, d_acc:0.59, g_loss:0.74
# epoch: 24801/24800, d_loss:0.71, d_acc:0.47, g_loss:0.73
# epoch: 24901/24900, d_loss:0.70, d_acc:0.44, g_loss:0.75
# epoch: 25001/25000, d_loss:0.74, d_acc:0.39, g_loss:0.74
# epoch: 25101/25100, d_loss:0.70, d_acc:0.52, g_loss:0.74
# epoch: 25201/25200, d_loss:0.68, d_acc:0.55, g_loss:0.73
# epoch: 25301/25300, d_loss:0.69, d_acc:0.50, g_loss:0.73
# epoch: 25401/25400, d_loss:0.71, d_acc:0.44, g_loss:0.73
# epoch: 25501/25500, d_loss:0.65, d_acc:0.58, g_loss:0.73
# epoch: 25601/25600, d_loss:0.68, d_acc:0.61, g_loss:0.77
# epoch: 25701/25700, d_loss:0.73, d_acc:0.39, g_loss:0.76
# epoch: 25801/25800, d_loss:0.70, d_acc:0.47, g_loss:0.75
# epoch: 25901/25900, d_loss:0.68, d_acc:0.64, g_loss:0.72
# epoch: 26001/26000, d_loss:0.70, d_acc:0.41, g_loss:0.73
# epoch: 26101/26100, d_loss:0.66, d_acc:0.61, g_loss:0.74
# epoch: 26201/26200, d_loss:0.66, d_acc:0.69, g_loss:0.75
# epoch: 26301/26300, d_loss:0.67, d_acc:0.58, g_loss:0.74
# epoch: 26401/26400, d_loss:0.71, d_acc:0.41, g_loss:0.74
# epoch: 26501/26500, d_loss:0.67, d_acc:0.59, g_loss:0.71
# epoch: 26601/26600, d_loss:0.71, d_acc:0.56, g_loss:0.76
# epoch: 26701/26700, d_loss:0.70, d_acc:0.50, g_loss:0.75
# epoch: 26801/26800, d_loss:0.68, d_acc:0.53, g_loss:0.74
# epoch: 26901/26900, d_loss:0.70, d_acc:0.45, g_loss:0.76
# epoch: 27001/27000, d_loss:0.69, d_acc:0.58, g_loss:0.72
# epoch: 27101/27100, d_loss:0.72, d_acc:0.41, g_loss:0.75
# epoch: 27201/27200, d_loss:0.66, d_acc:0.66, g_loss:0.72
# epoch: 27301/27300, d_loss:0.70, d_acc:0.53, g_loss:0.74
# epoch: 27401/27400, d_loss:0.69, d_acc:0.50, g_loss:0.72
# epoch: 27501/27500, d_loss:0.70, d_acc:0.50, g_loss:0.75
# epoch: 27601/27600, d_loss:0.68, d_acc:0.59, g_loss:0.72
# epoch: 27701/27700, d_loss:0.70, d_acc:0.52, g_loss:0.75
# epoch: 27801/27800, d_loss:0.71, d_acc:0.50, g_loss:0.74
# epoch: 27901/27900, d_loss:0.70, d_acc:0.53, g_loss:0.72
# epoch: 28001/28000, d_loss:0.68, d_acc:0.55, g_loss:0.74
# epoch: 28101/28100, d_loss:0.67, d_acc:0.58, g_loss:0.74
# epoch: 28201/28200, d_loss:0.70, d_acc:0.47, g_loss:0.74
# epoch: 28301/28300, d_loss:0.70, d_acc:0.45, g_loss:0.75
# epoch: 28401/28400, d_loss:0.68, d_acc:0.58, g_loss:0.72
# epoch: 28501/28500, d_loss:0.65, d_acc:0.66, g_loss:0.77
# epoch: 28601/28600, d_loss:0.68, d_acc:0.53, g_loss:0.73
# epoch: 28701/28700, d_loss:0.70, d_acc:0.41, g_loss:0.74
# epoch: 28801/28800, d_loss:0.67, d_acc:0.58, g_loss:0.74
# epoch: 28901/28900, d_loss:0.69, d_acc:0.52, g_loss:0.75
# epoch: 29001/29000, d_loss:0.69, d_acc:0.55, g_loss:0.76
# epoch: 29101/29100, d_loss:0.69, d_acc:0.44, g_loss:0.75
# epoch: 29201/29200, d_loss:0.70, d_acc:0.48, g_loss:0.74
# epoch: 29301/29300, d_loss:0.67, d_acc:0.53, g_loss:0.75
# epoch: 29401/29400, d_loss:0.69, d_acc:0.52, g_loss:0.73
# epoch: 29501/29500, d_loss:0.69, d_acc:0.62, g_loss:0.73
# epoch: 29601/29600, d_loss:0.70, d_acc:0.53, g_loss:0.78
# epoch: 29701/29700, d_loss:0.68, d_acc:0.48, g_loss:0.73
# epoch: 29801/29800, d_loss:0.68, d_acc:0.55, g_loss:0.77
# epoch: 29901/29900, d_loss:0.71, d_acc:0.50, g_loss:0.73

# %%
plt.plot(g_losses,label='g_losses')
plt.plot(d_losses,label='d_losses')
plt.legend()

# %%
! ls gan_images
# Out:
# 0.png	   13800.png  17800.png  21600.png  25600.png  29600.png  6600.png
# 10000.png  14000.png  18000.png  21800.png  25800.png  29800.png  6800.png
# 1000.png   1400.png   1800.png	 22000.png  26000.png  3000.png   7000.png
# 10200.png  14200.png  18200.png  2200.png   2600.png   3200.png   7200.png
# 10400.png  14400.png  18400.png  22200.png  26200.png  3400.png   7400.png
# 10600.png  14600.png  18600.png  22400.png  26400.png  3600.png   7600.png
# 10800.png  14800.png  18800.png  22600.png  26600.png  3800.png   7800.png
# 11000.png  15000.png  19000.png  22800.png  26800.png  4000.png   8000.png
# 11200.png  15200.png  19200.png  23000.png  27000.png  400.png	  800.png
# 11400.png  15400.png  19400.png  23200.png  27200.png  4200.png   8200.png
# 11600.png  15600.png  19600.png  23400.png  27400.png  4400.png   8400.png
# 11800.png  15800.png  19800.png  23600.png  27600.png  4600.png   8600.png
# 12000.png  16000.png  20000.png  23800.png  27800.png  4800.png   8800.png
# 1200.png   1600.png   2000.png	 24000.png  28000.png  5000.png   9000.png
# 12200.png  16200.png  200.png	 2400.png   2800.png   5200.png   9200.png
# 12400.png  16400.png  20200.png  24200.png  28200.png  5400.png   9400.png
# 12600.png  16600.png  20400.png  24400.png  28400.png  5600.png   9600.png
# 12800.png  16800.png  20600.png  24600.png  28600.png  5800.png   9800.png
# 13000.png  17000.png  20800.png  24800.png  28800.png  6000.png
# 13200.png  17200.png  21000.png  25000.png  29000.png  600.png
# 13400.png  17400.png  21200.png  25200.png  29200.png  6200.png
# 13600.png  17600.png  21400.png  25400.png  29400.png  6400.png

# %%
from skimage.io import imread
a = imread('gan_images/0.png')
plt.imshow(a)

# %%
a = imread('gan_images/200.png')
plt.imshow(a)

# %%
a = imread('gan_images/1000.png')
plt.imshow(a)

# %%
a = imread('gan_images/5000.png')
plt.imshow(a)

# %%
a = imread('gan_images/10000.png')
plt.imshow(a)

# %%
a = imread('gan_images/15000.png')
plt.imshow(a)

# %%
a = imread('gan_images/20000.png')
plt.imshow(a)

# %%
a = imread('gan_images/25000.png')
plt.imshow(a)

# %%
a = imread('gan_images/29800.png')
plt.imshow(a)
